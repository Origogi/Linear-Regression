# %% [markdown]
# <a href="https://colab.research.google.com/github/Origogi/Linear-Regression/blob/master/LinearRegression/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-638c4f45-1bc6-4b0d-9083-78367beb174f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-638c4f45-1bc6-4b0d-9083-78367beb174f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cost_revenue_clean.csv to cost_revenue_clean (1).csv

# %%
import io
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(io.BytesIO(myfile['cost_revenue_clean.csv' ]))

# %%
data

# %%
data.describe()

# %%
x = DataFrame(data, columns= ['production_budget_usd'])
y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
regression = LinearRegression()

# %%
regression.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regression.coef_  # theta_1 (기울기)
# Out:
# array([[3.11150918]])

# %%
regression.intercept_ # intercept (절편)
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x, y, alpha=0.3)
plt.plot(x, regression.predict(x), color='red', lineWidth=4)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('Worldwide Gross $')
plt.ylim(0, 3000000000)
plt.xlim(0, 450000000)

plt.show()

# %%
regression.score(x, y)
# Out:
# 0.5496485356985729
